# %% [markdown]
# # Wrangle-OpenStreetMap-Data
#
# On the particular project, I am using data mungling techniques to assess the quality of OpenStreetMap’s (OSM) data for the mumbai city regarding their consistency and uniformity. The data wrangling takes place programmatically, using Python for the most of the process and SQL for items that need further attention.
#
# The dataset describes the city of mumbai.Mumbai,India is the closest thing I have to a hometown in the India as I lived there for a good chunk of my childhood, so I was keen to take a look at it in this new, OpenStreetMap-based lens. The size of the dataset is 66 MB and can can be downloaded from here: https://mapzen.com/data/metro-extracts/metro/mumbai_india/
#
# About the project
#
# Scope
#
# OpenStreetMap (OSM) is a collaborative project to create a free editable map of the world. The creation and growth of OSM have been motivated by restrictions on use or availability of map information across much of the world, and the advent of inexpensive portable satellite navigation devices.
#
# On the specific project, I am using data from https://www.openstreetmap.org/node/16173235 and data mungling techniques, to assess the quality of their validity, accuracy, completeness, consistency and uniformity. The biggest part of the wrangling takes place programmatically using Python and then the dataset is entered into a SQL database for further examination of any remaining elements that need attention. Finally, I perform some basic exploration and express some ideas for additional improvements.
#
# Skills demonstrated
#
# Assessment of the quality of data for validity, accuracy, completeness, consistency and uniformity. Parsing and gathering data from popular file formats such as .xml and .csv. Processing data from very large files that cannot be cleaned with spreadsheet programs. Storing, querying, and aggregating data using SQL. Mumbai, India
#
# https://www.openstreetmap.org/node/16173235 https://mapzen.com/data/metro-extracts/metro/mumbai_india/
#
# Problems Encountered in the Map
#
# Problems Encountered in the Map Once the location was decided, I downloaded the full extract of the region and ran Python code to investigate any issues with the data. The following problems were discovered:
#
# Street Names: Incomplete ('hanuman raod ___') or incorrect names ('Zhopadpatti'), along with street abbreviations ('rd.' instead of 'Road')
#
# Postal Codes: Inconsistent postal code formats ('500023' and '120045') and incorrect post codes ('123')
#
# To tackle these issues, I had to create python scripts to clean each respective category of data. Auditing part is explained in Openstreetmap.ipynb notebook

# %% [markdown]
# I have created mumbai_sample file which is part of mumbai_india file and it can be used for various experiments before using those on main osm file, we can also get the idea about the format of osm file.

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "mumbai_india.osm"  # Replace this with your osm file
SAMPLE_FILE = "mumbai_sample.osm"

k = 500 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# Different types of tags mumbai_india file

# %%
import xml.etree.cElementTree as ET
import pprint
tags={}
def count_tags(sample_file):
    for event, elem in ET.iterparse(sample_file, events=("start",)):
        if elem.tag in tags.keys():
            tags[elem.tag] += 1
        else:
            tags[elem.tag] = 1
        #print tags
    return tags
tags = count_tags('mumbai_india.osm')
pprint.pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 13085,
#  'nd': 2356083,
#  'node': 2051208,
#  'osm': 1,
#  'relation': 3994,
#  'tag': 391731,
#  'way': 283963}

# %% [markdown]
# Tag types
#
#   "lower", for tags that contain only lowercase letters and are valid,
#
#   "lower_colon", for otherwise valid tags with a colon in their names,
#
#   "problemchars", for tags with problematic characters,
#
#   "other", for other tags that do not fall into the other three categories.

# %%
import xml.etree.cElementTree as ET
import pprint
import re
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
            if lower.search(element.attrib['k']):
              keys["lower"] += 1
            elif lower_colon.search(element.attrib['k']):
              keys["lower_colon"] += 1
            elif problemchars.search(element.attrib['k']):
              keys["problemchars"] += 1
            else:
              keys["other"] += 1
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys
keys = process_map('mumbai_india.osm')
pprint.pprint(keys)
# Out:
# {'lower': 375605, 'lower_colon': 15589, 'other': 530, 'problemchars': 7}

# %% [markdown]
# To find number of unique users in mumbai_india osm file

# %%
import xml.etree.cElementTree as ET
import pprint
import re
def get_user(element):
     if "uid" in element.attrib:
        return element.attrib["uid"]


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
       users.add(get_user(element))
       users.discard(None)
    return users
users = process_map('mumbai_india.osm')
#pprint.pprint(users)
len(users)
# Out:
# 1749

# %% [markdown]
# # Street Names
# There are two things the auditing function needed to accomplish:
# Replace any abbreviations of street types with the type completely spelled out.
#   1. 'Veer Savarkar Rd' -> 'Veer Savarkar Road'
#
# Replace incorrect or incomplete street names with the corrected/complete counterparts.
#
#   2. 'jhopadpatti' -> 'Slums'
#
# In order to discover problematic street names, I first had to use the regular expression (re) module to locate street types at the end of an address.

# %%
OSMFILE = "mumbai_india.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

# %% [markdown]
# Afterwards, I matched them against a list of acceptable street types. If they weren't in the list of expected types, they would be added to a dictionary as keys, with the addresses that contain the problematic cases as the values.
#
# Having this overview allowed me to determine what my auditing function needed to accomplish. I created a dictionaries for mapping/correcting purposes - 'mapping'. If my function came across a problematic street type, it would refer to that dictionaries for the corrected version to be replaced with.
#
# An analysis of the XML data, along with outside research on Google Maps and OpenStreetMaps, was needed to identify the missing street types for the incomplete street names.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "mumbai_india.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

#expected = ["Slums", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            
# UPDATE THIS VARIABLE
mapping = { "Jhopadpatti": "Slums",
            "Marg,": "Marg",
            "Mumbai,":"Mumbai",
            "ROad":"Road",
            "Rd":"Road",
            "Raod":"Road",
            "Rd.":"Road",
            "road":"Road"
            }




# UPDATE THIS VARIABLE


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        #if street_type not in expected:
        street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

def update_name(name, mapping):
    #print '\nSTART'
    #print name
    m = street_type_re.search(name)
    if m.group() in mapping.keys():        
        name=re.sub(street_type_re,mapping[m.group()],name)

    # YOUR CODE HERE

    return name

st_types = audit(OSMFILE)
#pprint.pprint(dict(st_types))

for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# Universal Mobile,DVD and Travelling shop => Universal Mobile,DVD and Travelling shop
# Vidhan Bhavan => Vidhan Bhavan
# kurla => kurla
# lalluabai compound => lalluabai compound
# THAKKAR BAPPA COLONY => THAKKAR BAPPA COLONY
# DATAR COLONY => DATAR COLONY
# P.L. Lokhande Marg,MHADA COLONY => P.L. Lokhande Marg,MHADA COLONY
# Thakurli Station Rd => Thakurli Station Road
# Veer Savarkar Rd => Veer Savarkar Road
# Bhandup Village Rd => Bhandup Village Road
# Sambhaji Nagar Rd => Sambhaji Nagar Road
# Pipeline Rd => Pipeline Road
# Vasai Station Rd => Vasai Station Road
# NL Rd => NL Road
# Marol Village Rd => Marol Village Road
# Vishnu Nagar Rd => Vishnu Nagar Road
# Yashavant Nagar Rd => Yashavant Nagar Road
# vishnu Nagar Rd => vishnu Nagar Road
# Balraj Sahni Rd => Balraj Sahni Road
# Wodehouse Rd => Wodehouse Road
# Koparkhairane Village Rd => Koparkhairane Village Road
# Datta Mandir Rd => Datta Mandir Road
# Belpada Rd => Belpada Road
# Goregaon Mulund Link Rd => Goregaon Mulund Link Road
# Agrawal Rd => Agrawal Road
# Carmichael Rd => Carmichael Road
# Sane Guruji Rd => Sane Guruji Road
# Shahid Mangal Pandey Rd => Shahid Mangal Pandey Road
# Mavla Maratha Rd => Mavla Maratha Road
# Off New Link Rd => Off New Link Road
# Station Rd => Station Road
# 35th Rd => 35th Road
# Kansai Road, Ambedkar chowk, => Kansai Road, Ambedkar chowk,
# CITIZEN STREET => CITIZEN STREET
# Hiranandani Estate Branch => Hiranandani Estate Branch
# Road No 25 => Road No 25
# Road No 26 => Road No 26
# Sector 14, CBD Belapur => Sector 14, CBD Belapur
# Sona Villa Sector 21 => Sona Villa Sector 21
# Sector 21 => Sector 21
# Sector 23 => Sector 23
# Main St, Hiranandani Gardens, => Main St, Hiranandani Gardens,
# thane => thane
# Infinite Corridoor => Infinite Corridoor
# avanthi vihar colony labhandi raipur => avanthi vihar colony labhandi raipur
# Kirol Road, Off LBS Marg, Patelwadi => Kirol Road, Off LBS Marg, Patelwadi
# National Highway 4 => National Highway 4
# Road No 4 => Road No 4
# Road Number 4 => Road Number 4
# RCF Colony Type 4 => RCF Colony Type 4
# R.S.C. Road Number 4 => R.S.C. Road Number 4
# Chhatrapati Shivaji Road Number 4 => Chhatrapati Shivaji Road Number 4
# GV Scheme Road 4 => GV Scheme Road 4
# MIDC Internal => MIDC Internal
# Essel World => Essel World
# A Wing, Abhishek Co Operative Housing Society, Santacruz Eas => A Wing, Abhishek Co Operative Housing Society, Santacruz Eas
# borivali east => borivali east
# Peltopherum Road (N S Road No 2) => Peltopherum Road (N S Road No 2)
# SION TROMBAY ROAD => SION TROMBAY ROAD
# KOPAR ROAD => KOPAR ROAD
# MUMBAI VASHI LINK ROAD => MUMBAI VASHI LINK ROAD
# hiranandani garden => hiranandani garden
# Road no 9 baingawadi => Road no 9 baingawadi
# Cama Industrial Estate,GoreGaon(E) => Cama Industrial Estate,GoreGaon(E)
# bardaan galli => bardaan galli
# Leela Cliff CHS => Leela Cliff CHS
# Gandhi Chauk => Gandhi Chauk
# Road No. 21, Opposite Passport Seva Kendra, => Road No. 21, Opposite Passport Seva Kendra,
# Dapoda Road, Amita complex, Opposite laxmi Shop => Dapoda Road, Amita complex, Opposite laxmi Shop
# Prabhat Colony => Prabhat Colony
# RCF Colony => RCF Colony
# R.C.F. Colony => R.C.F. Colony
# Mysore Colony => Mysore Colony
# mankhurd => mankhurd
# Plot no.3, Sector 2, Kharghar => Plot no.3, Sector 2, Kharghar
# Sector 3, Kharghar => Sector 3, Kharghar
# Sector 50 => Sector 50
# Lokmanya Tilak Nagar => Lokmanya Tilak Nagar
# Satya Nagar => Satya Nagar
# Shirdi Nagar => Shirdi Nagar
# Gandhi Nagar => Gandhi Nagar
# General Arun Kumar Vaidya Nagar => General Arun Kumar Vaidya Nagar
# Swami Gyan Jiwandas Marg => Swami Gyan Jiwandas Marg
# N M Joshi Marg => N M Joshi Marg
# Maulana Shaukat Ali Marg => Maulana Shaukat Ali Marg
# Krishna Changa Naik Marg => Krishna Changa Naik Marg
# Rao Khadye Marg => Rao Khadye Marg
# Sant Gadge Maharaj Marg => Sant Gadge Maharaj Marg
# Lokhandwala Marg => Lokhandwala Marg
# Sant Savta Mali Marg => Sant Savta Mali Marg
# N Bharucha Marg => N Bharucha Marg
# Mumbai Samachar Marg => Mumbai Samachar Marg
# Gurunanak Marg => Gurunanak Marg
# M G Ramchandran Marg => M G Ramchandran Marg
# Navghar Marg => Navghar Marg
# PG Kher Marg => PG Kher Marg
# Pravesh Marg => Pravesh Marg
# Vihar Lake Marg => Vihar Lake Marg
# Madhusudhan Kalelkar Marg => Madhusudhan Kalelkar Marg
# Sharadbhau Acharya Marg => Sharadbhau Acharya Marg
# Rajarambane Marg => Rajarambane Marg
# B D Savant Marg => B D Savant Marg
# Senapati Bapat Marg => Senapati Bapat Marg
# Aramnagar Part 1, Versova => Aramnagar Part 1, Versova
# St John's Road, Bandra West => St John's Road, Bandra West
# JP Road, Versova, Andheri West => JP Road, Versova, Andheri West
# Pali Market Road, Bandra West => Pali Market Road, Bandra West
# , Rizvi Park, S V Road, Santacruz West => , Rizvi Park, S V Road, Santacruz West
# St John's Street, Bandra West => St John's Street, Bandra West
# Oshiwara, Andheri West => Oshiwara, Andheri West
# Pali Junction, Dr BR Ambedkar Road, Bandra West => Pali Junction, Dr BR Ambedkar Road, Bandra West
# 16th Road, Bandra West => 16th Road, Bandra West
# Link Road Extension, Oshiwara, Andheri West => Link Road Extension, Oshiwara, Andheri West
# Off Link Road, Andheri West => Off Link Road, Andheri West
# Behind Goregaon Sports Club, Link Road, Malad West => Behind Goregaon Sports Club, Link Road, Malad West
# J.P Road, 7 Bungalows, Andheri West => J.P Road, 7 Bungalows, Andheri West
# Goregaon West => Goregaon West
# St Alexius Road, Bandra West => St Alexius Road, Bandra West
# Mahatma Phule Rd, Naupada, Thane West => Mahatma Phule Rd, Naupada, Thane West
# Interface Heights, Off link Road, Malad West => Interface Heights, Off link Road, Malad West
# Dr B.R Ambedkar Road, Bandra West => Dr B.R Ambedkar Road, Bandra West
# N Dutta Road, Four Bungalows, Andheri West => N Dutta Road, Four Bungalows, Andheri West
# JVPD Scheme Circle, Vile Parle West => JVPD Scheme Circle, Vile Parle West
# Dr BR Ambedkar Road, Bandra West => Dr BR Ambedkar Road, Bandra West
# Bank Of Maharashtra Lane, Seven Bungalows, Andheri West => Bank Of Maharashtra Lane, Seven Bungalows, Andheri West
# Gulmohar Road, Juhu Scheme, Vile Parle West => Gulmohar Road, Juhu Scheme, Vile Parle West
# Maitri Tower,Louiswadi,Thane West => Maitri Tower,Louiswadi,Thane West
# Gymkhana Road, Borivali West => Gymkhana Road, Borivali West
# #A-141 Four Bungalows,Lokhandwala Complex Road, Ambovali Village, Andheri West => #A-141 Four Bungalows,Lokhandwala Complex Road, Ambovali Village, Andheri West
# RK Patkar Marg (Waterfield Road) => RK Patkar Marg (Waterfield Road)
# Baji Pasalkar Marg (Saki Vihar Road) => Baji Pasalkar Marg (Saki Vihar Road)
# Choitram Gidwani Marg (Kolwada Borla Road) => Choitram Gidwani Marg (Kolwada Borla Road)
# Saras Baug => Saras Baug
# Next to Andhei subway, Old Nagardas Road, Andheri (E) => Next to Andhei subway, Old Nagardas Road, Andheri (E)
# Paranjpe 'B' Scheme road number 1, Vile Parle (E) => Paranjpe 'B' Scheme road number 1, Vile Parle (E)
# Sector- 06, plot 04 => Sector- 06, plot 04
# SVP Nagar, Lokhandwala Complex Road, 4 Bungalows,Andheri Lokhandwala => SVP Nagar, Lokhandwala Complex Road, 4 Bungalows,Andheri Lokhandwala
# Reliance Corporate Park => Reliance Corporate Park
# Lazarus rd => Lazarus rd
# Powai => Powai
# Supreme Business Park, South Avenue Hiranandani Powai => Supreme Business Park, South Avenue Hiranandani Powai
# Road No 3 => Road No 3
# Road Number 3 => Road Number 3
# Irani Wadi Road No 3 => Irani Wadi Road No 3
# Cross Road No 3 => Cross Road No 3
# ashok nagar hill no 3 => ashok nagar hill no 3
# Tejpal Scheme Road 3 => Tejpal Scheme Road 3
# Marigold Apt. , Panchpakhdi, Opp Nitin co & Honda showroom, => Marigold Apt. , Panchpakhdi, Opp Nitin co & Honda showroom,
# vasansha market => vasansha market
# Sector 7 => Sector 7
# sector 7 => sector 7
# Road Number 7 => Road Number 7
# St. George's Hospital Compound => St. George's Hospital Compound
# Dada Rege Marg aka. Shivaji Park Road no.3 => Dada Rege Marg aka. Shivaji Park Road no.3
# AGNIMATA TEMPLE => AGNIMATA TEMPLE
# Chendani koliwada => Chendani koliwada
# B C Chatterjee Marg (Main Avenue) => B C Chatterjee Marg (Main Avenue)
# D Saraswati Marg (Central Avenue) => D Saraswati Marg (Central Avenue)
# Kamalakarpant L Walawalkar Mg => Kamalakarpant L Walawalkar Mg
# Retibandar, Ghodbunder, Mira Bhayandar => Retibandar, Ghodbunder, Mira Bhayandar
# J.v.link.rod => J.v.link.rod
# Jaishankar Yagnik Road (Flank Road West) => Jaishankar Yagnik Road (Flank Road West)
# Shivaji Nager,T.P.Road,Bhandup (West) => Shivaji Nager,T.P.Road,Bhandup (West)
# Evershine Nagar, Malad (West) => Evershine Nagar, Malad (West)
# Nere-Chipale, => Nere-Chipale,
# Sector 20 => Sector 20
# Nehru Road Ext => Nehru Road Ext
# Ghatkopar FOB => Ghatkopar FOB
# Govandi FOB => Govandi FOB
# Ashok Kedare Chowk => Ashok Kedare Chowk
# Chintamani Chowk => Chintamani Chowk
# Doctor Shyama Prasad Mukherjee Chowk => Doctor Shyama Prasad Mukherjee Chowk
# datta mandhiar foot path => datta mandhiar foot path
# 90/ A, Near Holy Family Hospital, Hill Rd, Bandra West, Mumbai, Maharashtra => 90/ A, Near Holy Family Hospital, Hill Rd, Bandra West, Mumbai, Maharashtra
# Sector 21, Nerul, Navi Mumbai, Maharashtra => Sector 21, Nerul, Navi Mumbai, Maharashtra
# govandi => govandi
# Nariman Point => Nariman Point
# Backbay Reclamation, Nariman Point => Backbay Reclamation, Nariman Point
# 9 A nerul, Uran Road, Sector 19A, Nerul, Navi Mumbai, => 9 A nerul, Uran Road, Sector 19A, Nerul, Navi Mumbai
# JK Sawant Marg, => JK Sawant Marg
# Karjat, MH => Karjat, MH
# Paud Lonavla Road, Mulshi => Paud Lonavla Road, Mulshi
# Dr. Dadabhai Naoroji => Dr. Dadabhai Naoroji
# l.j.road => l.j.road
# Sector 6 Market => Sector 6 Market
# malad west => malad west
# Sumer castle => Sumer castle
# M.G.Road => M.G.Road
# Ramchandra Gali => Ramchandra Gali
# new link road => new link Road
# st anthony church  road => st anthony church  Road
# mohd ali road => mohd ali Road
# ghatkapar/mankhurd link road => ghatkapar/mankhurd link Road
# jay bhavani mata road => jay bhavani mata Road
# LBS Marg 90 feet road => LBS Marg 90 feet Road
# 2nd floor swadesi market kalbadevi road => 2nd floor swadesi market kalbadevi Road
# saba road => saba Road
# video road => video Road
# Shankar Pawse road => Shankar Pawse Road
# devidas ext road => devidas ext Road
# tanki road => tanki Road
# father peter periera road => father peter periera Road
# 24th road => 24th Road
# Godrej Hill road => Godrej Hill Road
# 4th road => 4th Road
# Gograswadi, Patharli road => Gograswadi, Patharli Road
# Kamothe main road => Kamothe main Road
# Barave gaon road => Barave gaon Road
# Sher-e-Punjab road => Sher-e-Punjab Road
# 90 feet road => 90 feet Road
# M. G. cross road => M. G. cross Road
# Mulshi road => Mulshi Road
# l.u.gadkari road => l.u.gadkari Road
# 90ft road => 90ft Road
# Manish Market service road => Manish Market service Road
# kirol road => kirol Road
# mohmmad road => mohmmad Road
# Raghunath Vihar road => Raghunath Vihar Road
# bharda wadi road => bharda wadi Road
# off Ghodhbunder road => off Ghodhbunder Road
# Vashi station road => Vashi station Road
# NMMT road => NMMT Road
# bhivandi-kalher road => bhivandi-kalher Road
# Harbour Heights service road => Harbour Heights service Road
# amrutnager road => amrutnager Road
# st anthony church road => st anthony church Road
# Juhu Tara road => Juhu Tara Road
# market road => market Road
# Father peter periera road => Father peter periera Road
# road => Road
# Khokhani Estate, Opp. Neelkanth Industrial Estate, Near Saibaba Mandir, Sativali.Palgarh: => Khokhani Estate, Opp. Neelkanth Industrial Estate, Near Saibaba Mandir, Sativali.Palgarh:
# Parvati Cross => Parvati Cross
# Prabhat colony => Prabhat colony
# railway colony => railway colony
# Datar colony => Datar colony
# sec-2, Khanda colony => sec-2, Khanda colony
# Amar Mahal , Chembur => Amar Mahal , Chembur
# Tilak Nagar, Chembur => Tilak Nagar, Chembur
# Azad Nagar, Sandoz Baug Post, => Azad Nagar, Sandoz Baug Post,
# Bora Bazaar Street, Siddhi Vinayak CHS, Fort, CST => Bora Bazaar Street, Siddhi Vinayak CHS, Fort, CST
# Indradarshan Crossroad => Indradarshan Crossroad
# Vashi => Vashi
# m ward marg => m ward marg
# vidyarthi marg => vidyarthi marg
# Kailash Esplanade, LBS marg => Kailash Esplanade, LBS marg
# sitaram palturam murai marg => sitaram palturam murai marg
# H.N.A azmi marg => H.N.A azmi marg
# P L Lokhande marg => P L Lokhande marg
# Near dwarka shop p.l.lokhande marg => Near dwarka shop p.l.lokhande marg
# Hathayogi nikam guruji marg => Hathayogi nikam guruji marg
# gokul marg => gokul marg
# Gokhale Road North => Gokhale Road North
# Near Dukes Factory, Waman Tukaram Patil Marg (Ghatkopar Sewri Wadala Road), Deonar => Near Dukes Factory, Waman Tukaram Patil Marg (Ghatkopar Sewri Wadala Road), Deonar
# Sion Trombay Road, Deonar => Sion Trombay Road, Deonar
# ashirwad hospital => ashirwad hospital
# sant nirankari => sant nirankari
# Baudi Lane, Orlem Malad => Baudi Lane, Orlem Malad
# Dominic Lane, Orlem Malad => Dominic Lane, Orlem Malad
# Veer Vithaldas Chandan Street (De Souza Street) => Veer Vithaldas Chandan Street (De Souza Street)
# Road No 2 => Road No 2
# Pokhran Road 2 => Pokhran Road 2
# D.P. road No. 2 => D.P. road No. 2
# Road Number 2 => Road Number 2
# Cross Road No 2 => Cross Road No 2
# Hanuman Cross Rd. No. 2 => Hanuman Cross Rd. No. 2
# L. J. Cross Road No. 2 => L. J. Cross Road No. 2
# Gawde Road 2 => Gawde Road 2
# Sector 6 => Sector 6
# J.V.P.D Scheme Road 6 => J.V.P.D Scheme Road 6
# Chitalsar => Chitalsar
# Hendrapada => Hendrapada
# Kalbadevi => Kalbadevi
# Nana Shankar Rd, Retibandar, Ghodbunder, Mira Bhayandar, => Nana Shankar Rd, Retibandar, Ghodbunder, Mira Bhayandar,
# Sodawala Lane => Sodawala Lane
# Ice Factory Lane => Ice Factory Lane
# St. Anne's Lane => St. Anne's Lane
# Khetwadi 12th Lane => Khetwadi 12th Lane
# 1st Pasta Lane => 1st Pasta Lane
# Sadashiva Cross Lane => Sadashiva Cross Lane
# Dominic Lane => Dominic Lane
# Juhu Lane => Juhu Lane
# Dontad Cross Lane => Dontad Cross Lane
# Khetwadi 5th Lane => Khetwadi 5th Lane
# 14th Lane => 14th Lane
# Sindhi Lane => Sindhi Lane
# Goshala Lane => Goshala Lane
# Baudi Lane => Baudi Lane
# Thanawala Lane => Thanawala Lane
# 4th Pasta Lane => 4th Pasta Lane
# Shankar Lane => Shankar Lane
# Cama Lane => Cama Lane
# Raviraj Oberoi Complex, Inside SAB TV Lane => Raviraj Oberoi Complex, Inside SAB TV Lane
# sector 34 B => sector 34 B
# Zainee Shopping Centre, Opposite Akash Talkies => Zainee Shopping Centre, Opposite Akash Talkies
# Gokuldham => Gokuldham
# Satelliete Garden, Gokuldham => Satelliete Garden, Gokuldham
# HATTIMOHALLA => HATTIMOHALLA
# Niedersachsenring => Niedersachsenring
# T. T. C Industrial Area, M. I. D. C, Rabale, Navi Mumbai - 400701, Amrut Dham, Gothivali Village, Sector 30, Ghansoli => T. T. C Industrial Area, M. I. D. C, Rabale, Navi Mumbai - 400701, Amrut Dham, Gothivali Village, Sector 30, Ghansoli
# Ghansoli => Ghansoli
# Evershine Nagar, Malad (W) => Evershine Nagar, Malad (W)
# King's Circle Flyover => King's Circle Flyover
# Marine Lines Flyover => Marine Lines Flyover
# Majiwada Flyover => Majiwada Flyover
# Karjat => Karjat
# Tilakwadi, Belagavi Belgaum => Tilakwadi, Belagavi Belgaum
# Road No.6 => Road No.6
# Additional Kalyan Bhiwandi MIDC Industrial Area, Plot No. 1, Village Kone, => Additional Kalyan Bhiwandi MIDC Industrial Area, Plot No. 1, Village Kone,
# Road No.4 => Road No.4
# aqsa masjid => aqsa masjid
# Plot No.2 => Plot No.2
# Hanuman Cross Rd. No.1 => Hanuman Cross Rd. No.1
# L.J. Road No.1 => L.J. Road No.1
# Nagdevi Path => Nagdevi Path
# D N Path => D N Path
# Shivaji Path => Shivaji Path
# Adi Murzban Path => Adi Murzban Path
# Lt Prakash Kotnis Path => Lt Prakash Kotnis Path
# shree satidham => shree satidham
# neelam nagar, phase-2 => neelam nagar, phase-2
# jacob circle => jacob circle
# Bandra Kurla Complex Road => Bandra Kurla Complex Road
# Wing Mess Road => Wing Mess Road
# Dharavi Main Road => Dharavi Main Road
# Saraswati Road => Saraswati Road
# Ganesh Gawde Road => Ganesh Gawde Road
# Rambhau Salgaonkar Road => Rambhau Salgaonkar Road
# Maharshi Karve Road => Maharshi Karve Road
# Off Veera Desai Road => Off Veera Desai Road
# Balaji Mandir Road => Balaji Mandir Road
# 33rd Road => 33rd Road
# Raja Shivaji School Road => Raja Shivaji School Road
# 90 Feet Road => 90 Feet Road
# Powai Road => Powai Road
# Jame Jamshed Road => Jame Jamshed Road
# Pipe Line Road => Pipe Line Road
# Postal Colony Road => Postal Colony Road
# Bhau Daji Road => Bhau Daji Road
# Chhatrapati Shivaji Maharaj Road => Chhatrapati Shivaji Maharaj Road
# Charat Singh Road => Charat Singh Road
# Thane Ghodbunder Road => Thane Ghodbunder Road
# Agasan Road => Agasan Road
# Mohammed Ali Road => Mohammed Ali Road
# Zaver Road => Zaver Road
# Matheran Road => Matheran Road
# Bhandarkar Road => Bhandarkar Road
# Deonar Road => Deonar Road
# Mahakali Caves Road => Mahakali Caves Road
# Sarojini Naidu Road => Sarojini Naidu Road
# VIjay Raut Road => VIjay Raut Road
# Bharucha Road => Bharucha Road
# Mumbai - Pune Road => Mumbai - Pune Road
# Kopar Road => Kopar Road
# Dr BR Ambedkar Road => Dr BR Ambedkar Road
# Poddar Road => Poddar Road
# 60 Feet Road => 60 Feet Road
# Navghar Road => Navghar Road
# Lajpatrai Road => Lajpatrai Road
# Dr. Peter Dias Road => Dr. Peter Dias Road
# Behind M.G. Road => Behind M.G. Road
# St Dominic Street;7th Road => St Dominic Street;7th Road
# St Louis Convent Road => St Louis Convent Road
# Chendani Bunder Road => Chendani Bunder Road
# Chaphekar Road => Chaphekar Road
# LT Road => LT Road
# Vichumbe Road => Vichumbe Road
# Kherwadi Road => Kherwadi Road
# Purushottam Kheraj (Dumping) Road => Purushottam Kheraj (Dumping) Road
# Gyan Vikas Road => Gyan Vikas Road
# Janki Kutir Juhu Church Road, Mumbai => Janki Kutir Juhu Church Road, Mumbai
# Liberty Tower, Plot No. K 10, Behind Reliable Plaza, Thane-Belapur Road, Airoli Navi Mumbai => Liberty Tower, Plot No. K 10, Behind Reliable Plaza, Thane-Belapur Road, Airoli Navi Mumbai
# Opposite Bon Bon, Four Bungalows, Andheri West, Mumbai => Opposite Bon Bon, Four Bungalows, Andheri West, Mumbai
# Lokhandawala Road, 4 Bungalows, Andheri (West), Mumbai => Lokhandawala Road, 4 Bungalows, Andheri (West), Mumbai
# New Link Road, Andheri West, Mumbai => New Link Road, Andheri West, Mumbai
# Rd S => Rd S
# Kolsewadi => Kolsewadi
# Asalpha => Asalpha
# Veer Savarkar Rd (gavthan road) => Veer Savarkar Rd (gavthan road)
# Pawana Nagar Taluka Maval => Pawana Nagar Taluka Maval
# Creak Crest, Model Town, Four Bunglow => Creak Crest, Model Town, Four Bunglow
# Jagnnath Mandir Road,Satyanagar, Sakinaka => Jagnnath Mandir Road,Satyanagar, Sakinaka
# Satyanagar, Sakinaka => Satyanagar, Sakinaka
# Gokhale Road North, Amarhind Mandal => Gokhale Road North, Amarhind Mandal
# Eastern Expressway => Eastern Expressway
# Caser Mill Circle => Caser Mill Circle
# Harinivas Circle => Harinivas Circle
# Western Express Highway => Western Express Highway
# Sion Panvel Highway => Sion Panvel Highway
# Eastern Express Highway => Eastern Express Highway
# old Mumbai pune Highway => old Mumbai pune Highway
# eastern Express Highway => eastern Express Highway
# Bandra Kurla Complex, Off Western Express Highway => Bandra Kurla Complex, Off Western Express Highway
# Mumbai Agra National Highway => Mumbai Agra National Highway
# Erangal Beach, Madh Island, Marve Road, Malad East, => Erangal Beach, Madh Island, Marve Road, Malad East,
# 186, New Andheri Link Road, Bhagat Singh Colony,, Andheri East, => 186, New Andheri Link Road, Bhagat Singh Colony,, Andheri East,
# 5th Floor, Chakala Pragati CHS, J B Nagar, Andheri East => 5th Floor, Chakala Pragati CHS, J B Nagar, Andheri East
# Kher Nagar, Bandra East => Kher Nagar, Bandra East
# Ashok Nagar, Marol Naka, Off Military Road, Andheri East => Ashok Nagar, Marol Naka, Off Military Road, Andheri East
# Tucker Heights, Plot No 197, Andheri East => Tucker Heights, Plot No 197, Andheri East
# Dattapada Road, Borivali East => Dattapada Road, Borivali East
# Near Sai Baba Mandir, Pathanwadi Bus Stand, Malad East => Near Sai Baba Mandir, Pathanwadi Bus Stand, Malad East
# Com. Harbanslal Marg, Sion East => Com. Harbanslal Marg, Sion East
# d-sector, f/line, cheeta camp, => d-sector, f/line, cheeta camp,
# Unique Garden => Unique Garden
# Rd5-Rd6 Connector => Rd5-Rd6 Connector
# JVLR => JVLR
# Walawalkar Marg, Andheri(West), => Walawalkar Marg, Andheri(West),
# Aramnagar Part 1 => Aramnagar Part 1
# Pokhran Road 1 => Pokhran Road 1
# Road No 1 => Road No 1
# Koldongri 1 => Koldongri 1
# Aramnagar 1 => Aramnagar 1
# Gawde Road 1 => Gawde Road 1
# Road Number 1 => Road Number 1
# Kannamwar Nagar 1 , Vikhroli (east) => Kannamwar Nagar 1 , Vikhroli (east)
# Vidyavihar skywalk => Vidyavihar skywalk
# Hatutma Sitaram Ghadi Gaonkar Street => Hatutma Sitaram Ghadi Gaonkar Street
# Kalyan Street => Kalyan Street
# St Dominic Street => St Dominic Street
# Sarang Street => Sarang Street
# Tantanpura Street => Tantanpura Street
# High Street => High Street
# Yogiraj Street => Yogiraj Street
# Main Street => Main Street
# Technology Street => Technology Street
# Wallace Street => Wallace Street
# Cawasji Patel Street => Cawasji Patel Street
# St. Anthony Street => St. Anthony Street
# Saint John's Street => Saint John's Street
# Rope Walk Street => Rope Walk Street
# Perin Nariman Street => Perin Nariman Street
# Dalal Street => Dalal Street
# St John's Street => St John's Street
# Lamington Street => Lamington Street
# Dadiseth Agiary Street => Dadiseth Agiary Street
# Forest Street => Forest Street
# Forjet Street => Forjet Street
# Nowroji Ferdonji Street => Nowroji Ferdonji Street
# TTC Ind. Area, Mahape (Pawane) => TTC Ind. Area, Mahape (Pawane)
# Ground Floor, Thakur Shopping Mall & Multiplex => Ground Floor, Thakur Shopping Mall & Multiplex
# 1st Floor, Thakur Shopping Mall & Multiplex => 1st Floor, Thakur Shopping Mall & Multiplex
# shiwaji chowk => shiwaji chowk
# Road no 33 => Road no 33

# %% [markdown]
# # Postal Codes
#
# Postal codes of Mumbai all start with '40' and all are of 6 digits therefore for auditing postcodes it was important to ensure the postal codes are in the 6-digit format
# To locate and extract the 6-digit zip code in cases where there are irrelevant or too much information - i.e. random white spaces or an additional strings after the zip code.
# Example conversions:
# 1. 400076,India
#
# To identify problems with postal codes, I used a function that would search through the XML data for every instance of a postal code, and add it to a set of unique postal codes if it satisfies above mentioned conditions.
# The audit function can be found below.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "mumbai_india.osm"
tree = ET.parse(OSMFILE)
root = tree.getroot()

postal_type_re = re.compile('^(4)(0)\d{4}$')



def audit_postal_code(postal_types,postal_value):
    m = postal_type_re.search(postal_value)
    if m:
        postal_type=m.group()
        postal_types[postal_type].add(postal_value)

def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    postal_types=defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag in["node", "way", "relation"] :
            for tag in elem.iter("tag"):
                if is_postal_code(tag):
                    audit_postal_code(postal_types,tag.attrib['v'])
    osm_file.close()
    return postal_types


#audit(SAMPLE_FILE)
#audit(OSMFILE)
pprint.pprint(dict(audit(OSMFILE)))
# Out:
# {'400001': set(['400001']),
#  '400002': set(['400002']),
#  '400003': set(['400003']),
#  '400004': set(['400004']),
#  '400005': set(['400005']),
#  '400007': set(['400007']),
#  '400008': set(['400008']),
#  '400009': set(['400009']),
#  '400010': set(['400010']),
#  '400011': set(['400011']),
#  '400012': set(['400012']),
#  '400013': set(['400013']),
#  '400014': set(['400014']),
#  '400015': set(['400015']),
#  '400016': set(['400016']),
#  '400017': set(['400017']),
#  '400018': set(['400018']),
#  '400019': set(['400019']),
#  '400020': set(['400020']),
#  '400021': set(['400021']),
#  '400022': set(['400022']),
#  '400023': set(['400023']),
#  '400024': set(['400024']),
#  '400025': set(['400025']),
        v1 = i.get("v")
        m1 = regex.match(v1)
        if not m1:
            counttotal = counttotal +1
            if len(v1) <> 6:
                v1 = v1.replace(" ","")
                v1 = v1.replace(",","")
                v1 = v1.replace("-","")
                v1 = v1.replace('"',"")
                v1 = v1.replace('55',"5")
                m2 = regex.match(v1)
                if not m2:
                    wp.append(v1)
                    count = count +1
            elif len(v1) == 6:
                wp.append(v1)
                count = count +1

print wp
print count
#print counttotal
# Out:
# ['421501', '421503', '410206', '410210', '410210', '410210', '410210', '412108', '410701', '421202', '421202', '4000607', '40058', '421501', '63103', '421501', '421501', '410201', '410201', '410201', '4000082', '400059.', '410210', '110092', '123', '410209', '410209', '410209', '421302', '410206', '4000072', '410206', '421301', '421301', '4000072', '421306', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410208', '421501', '410206', '40076', '560023', '590006', '492006', '410210', '410206', '560092', '410206', '410206', '410206', '410206', '410206', '410206', '410206', '410206', '410206', '410221', '410102', '410206', '421601', '410206', '421005', '410206', '421501', '410221', '410206', '410206', '48147', '410218', '421201', '421302', '410206', '412108', '412108', '421501', '421501', '410206', '421311', '400076India', '400076India', '410210', '40081', '410210', '410201', '410201', '40001', '40049', '421501', '410406', '412108', '400076India', '421302', '500053', '421201', '410206', '43', '40051', '400076India', '421202', '410206', '410210', '421302', '560103', '500054', '410210', '410210', '410210', '410210', '410218', '421301', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410206', '410206', '410210', '410210', '421301', '410210', '421002', '421203', '410206', '410209', '421306', '421202', '421202', '421503', '410401', '410210', '410210', '410210', '410210', '410210', '410210', '410210', '410208', '410208', '410209', '410210', '410206', '412108', '421004', '410206', '421201']
# 167

# %% [markdown]
# This function is use to update the postal codes by which all postal codes from bad postals mentioned above will be replaced by '000000'.

# %%
def update_postcode(postcode):
    search = re.search(r'^\D*(\d{6}).*',postcode)
    search1 = re.search('^(4)(0)\d{4}$',postcode)
    if search1:
        return search.group(1) 
    else :
        return '000000'
for i in tree.getiterator('tag'):
    k1 = i.get("k")
    if k1 == "addr:postcode":
        v1 = i.get("v")
        print  update_postcode(v1)
# Out:
# 000000
# 000000
# 000000
# 400050
# 400050
# 400050
# 400050
# 400615
# 400614
# 000000
# 400005
# 000000
# 400020
# 400086
# 400601
# 400022
# 400606
# 400039
# 400005
# 400001
# 400039
# 400020
# 000000
# 400039
# 000000
# 400039
# 400607
# 400020
# 400069
# 400703
# 400610
# 400016
# 400071
# 400067
# 400005
# 400049
# 400072
# 400710
# 400093
# 400054
# 400052
# 400088
# 000000
# 400001
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400057
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400607
# 400057
# 400007
# 400050
# 400076
# 400706
# 400074
# 400614
# 400614
# 400071
# 400076
# 400016
# 400066
# 400007
# 400005
# 400005
# 400103
# 400103
# 400005
# 000000
# 400022
# 400049
# 400049
# 400049
# 400057
# 400057
# 400088
# 400606
# 400606
# 400606
# 400066
# 400053
# 400091
# 400091
# 400601
# 400601
# 400601
# 400001
# 400038
# 400019
# 400034
# 400005
# 400709
# 400705
# 400053
# 400033
# 400080
# 400080
# 400061
# 400061
# 400053
# 400053
# 400053
# 400053
# 400061
# 400061
# 400061
# 400053
# 400053
# 000000
# 400053
# 400053
# 400053
# 400053
# 400053
# 400058
# 400053
# 400053
# 400053
# 400053
# 400053
# 400053
# 400053
# 400053
# 400053
# 
node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
  
    # YOUR CODE HERE
    
    if element.tag == 'node':
        for i in NODE_FIELDS:
            node_attribs[i] = element.attrib[i]
        for tag in element.iter("tag"):
            tag_dict= {}
            # Calling the cleaning function
            # replace name with the value of the attribute
            if tag.attrib['k'] == 'addr:street':
                tag.attrib['v'] = update_name(tag.attrib['v'], mapping)
            if tag.attrib["k"] == 'addr:postcode':
                tag.attrib["v"] = update_postcode(tag.attrib["v"])
            
            tag_dict['id'] = node_attribs['id']
            key = tag.attrib['k']
            
            if re.search(PROBLEMCHARS, tag.attrib['k']):
                pass
            if re.search(LOWER_COLON, tag.attrib['k']):
                pass
            if ':' in tag.attrib['k']:
                type = key[: key.index(':')]
                key = key[key.index(':')+1 :]   
            else:
                type = 'regular'   
            
            tag_dict['key'] = key
            tag_dict['value'] = tag.attrib['v']
            tag_dict['type'] = type
            tags.append(tag_dict)
            
            #pprint.pprint(dict(tag_dict))
            
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        for way in WAY_FIELDS:
            way_attribs[way] = element.attrib[way]
        for tag in element.iter("tag"):
            tag_dict1= {}

            if tag.attrib["k"] == 'addr:postcode':
                tag.attrib["v"] = update_postcode(tag.attrib["v"])
            tag_dict1['id'] = way_attribs['id']
            key = tag.attrib['k']
            
            if re.search(PROBLEMCHARS, tag.attrib['k']):
                pass
            if re.search(LOWER_COLON, tag.attrib['k']):
                pass
            if ':' in tag.attrib['k']:
                type = key[: key.index(':')]
                key = key[key.index(':')+1 :]
            else:
                type = 'regular' 
            tag_dict1['key'] = key
            tag_dict1['value'] = tag.attrib['v']
            tag_dict1['type'] = type
            tags.append(tag_dict1) 
            
        i= 0
        for tag in element.iter("nd"):
            way_dict = {}
            way_dict["id"] = way_attribs["id"]
            way_dict["node_id"] = tag.attrib["ref"]
            way_dict["position"] = i
            way_nodes.append(way_dict)
            i +=1    
        
        # pprint.pprint(dict(way_dict)) 
            
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'wb') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'wb') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'wb') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'wb') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'wb') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)

# %% [markdown]
# # Importing CSV Files to SQL Database
#
# With the CSV files written, I was able to begin the process of importing the data into a SQL database. In my case, I used SQLite 3 and accessed it through notebook to first create database named a Mumbai_india,then add all data from csv files to database.
#
# There are two steps I needed to accomplish to complete this task:
#
# 1. Create five tables on sqlite based on a schema that matches their respective .csv files
# 2. Import each .csv file into the appropriate table

# %%
import csv, sqlite3
from pprint import pprint
sql_file="Mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()

cur.execute('''DROP TABLE IF EXISTS nodes;''')
con.commit()


cur.execute("CREATE TABLE nodes(id INTEGER, lat REAL, lon REAL, user TEXT, uid INTEGER, version TEXT, changeset INTEGER, timestamp DATE);") # use your column names here
con.commit()
with open('nodes.csv','rb') as thr: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(thr) # comma is default delimiter
    to_db = [(i['id'].decode("utf-8"),i['lat'].decode("utf-8"),i['lon'].decode("utf-8"),i['user'].decode("utf-8"),i['uid'].decode("utf-8"),i['version'].decode("utf-8"),i['changeset'].decode("utf-8"),i['timestamp'].decode("utf-8")) for i in dr]

cur.executemany("INSERT INTO nodes (id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?,?,?,?,?,?,?,?);", to_db)
con.commit()
#con.close()


cur.execute('''DROP TABLE IF EXISTS nodes_tags;''')
con.commit()

cur.execute("CREATE TABLE Nodes_tags (id INTEGER, key TEXT, value TEXT, type TEXT);") # use your column names here
con.commit()
with open('nodes_tags.csv','rb') as thr: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(thr) # comma is default delimiter
    to_db = [(i['id'].decode("utf-8"),i['key'].decode("utf-8"),i['value'].decode("utf-8"),i['type'].decode("utf-8")) for i in dr]

cur.executemany("INSERT INTO Nodes_tags (id, key, value, type) VALUES (?,?,?,?);", to_db)
con.commit()

cur.execute('''DROP TABLE IF EXISTS ways;''')
con.commit()


cur.execute("CREATE TABLE ways (id INTEGER, user TEXT, uid INTEGER, version TEXT, changeset INTEGER, timestamp DATE);") # use your column names here
con.commit()
with open('ways.csv','rb') as thr: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(thr) # comma is default delimiter
    to_db = [(i['id'].decode("utf-8"),i['user'].decode("utf-8"),i['uid'].decode("utf-8"),i['version'].decode("utf-8"),i['changeset'].decode("utf-8"),i['timestamp'].decode("utf-8")) for i in dr]

cur.executemany("INSERT INTO ways (id , user, uid, version, changeset, timestamp) VALUES (?,?,?,?,?,?);", to_db)
con.commit()


cur.execute('''DROP TABLE IF EXISTS ways_tags;''')
con.commit()


cur.execute("CREATE TABLE ways_tags (id INTEGER, key TEXT, value TEXT, type TEXT);") # use your column names here
con.commit()
with open('ways_tags.csv','rb') as thr: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(thr) # comma is default delimiter
    to_db = [(i['id'].decode("utf-8"),i['key'].decode("utf-8"),i['value'].decode("utf-8"),i['type'].decode("utf-8")) for i in dr]


cur.executemany("INSERT INTO ways_tags (id, key, value, type) VALUES (?,?,?,?);", to_db)
con.commit()



cur.execute('''DROP TABLE IF EXISTS ways_nodes;''')
con.commit()

cur.execute("CREATE TABLE ways_nodes (id INTEGER, node_id INTEGER, position INTEGER);") # use your column names here
con.commit()
with open('ways_nodes.csv','rb') as thr: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(thr) # comma is default delimiter
    to_db = [(i['id'].decode("utf-8"),i['node_id'].decode("utf-8"),i['position'].decode("utf-8")) for i in dr]
    
cur.executemany("INSERT INTO ways_nodes (id, node_id, position) VALUES (?,?,?);", to_db)
con.commit()

# %% [markdown]
# # Data Overview
# In this section, I'll execute a number of SQL queries in order to analyze the dataset.

# %% [markdown]
# Users with most numbers of contributions.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT user,count(*) FROM nodes GROUP BY user ORDER BY count(*) DESC LIMIT 5')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'parambyte', 69327),
#  (u'PlaneMad', 68363),
#  (u'anushap', 62553),
#  (u'Ashok09', 62208),
#  (u'Narsimulu', 55611)]

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT key,count(*) FROM ways_tags GROUP BY key ORDER BY count(*) DESC LIMIT 5')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'building', 223631),
#  (u'highway', 40437),
#  (u'name', 11741),
#  (u'oneway', 4466),
#  (u'source', 4142)]

# %% [markdown]
# Total number of unique users.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT COUNT(DISTINCT(e.uid)) FROM (SELECT uid FROM nodes UNION ALL SELECT uid FROM ways) e')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(1739,)]

# %% [markdown]
# Total number of users who contributed for less than 5 times.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT COUNT(*) FROM (SELECT e.user, COUNT(*) as num FROM (SELECT user FROM nodes UNION ALL SELECT user FROM ways) as e GROUP BY e.user HAVING num<=5)  u')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(910,)]

# %% [markdown]
# Different types of cuisines available in mumbai and number of restaurants it is available in.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT nodes_tags.value, COUNT(*) as num FROM nodes_tags JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value="restaurant") as i ON nodes_tags.id=i.id WHERE nodes_tags.key="cuisine" GROUP BY nodes_tags.value ORDER BY num DESC')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'indian', 66),
#  (u'regional', 21),
#  (u'pizza', 14),
#  (u'vegetarian', 13),
#  (u'chinese', 12),
#  (u'italian', 11),
#  (u'burger', 5),
#  (u'international', 5),
#  (u'seafood', 4),
#  (u'asian', 3),
#  (u'South_Indian', 2),
#  (u'all_types_of_food', 2),
#  (u'lebanese', 2),
#  (u'Indian,_Chinese_etc', 1),
#  (u'Seafood', 1),
#  (u'Vegetarian_Restaurant', 1),
#  (u'american', 1),
#  (u'cafe', 1),
#  (u'chicken;fish;indian', 1),
#  (u'chicken;kebab;indian', 1),
#  (u'chicken_,fish,cafe', 1),
#  (u'fast_food', 1),
#  (u'grill;coffee_shop;asian;noodles;fish_and_chips;diner;chicken;italian_pizza;indian;curry;fish;french;friture;chinese;barbecue',
#   1),
#  (u'indian;south_indian', 1),
#  (u'indian_aagri', 1),
#  (u'italian_pizza;pizza', 1),
#  (u'lebanese,_chinese,_indian', 1),
#  (u'local', 1),
#  (u'mediterranean', 1),
#  (u'only_vegiterian', 1),
#  (u'oriental', 1),
#  (u'persian', 1),
#  (u'sad_food', 1),
#  (u'south Indian; Punjabi; agari; malwani; Chinese', 1),
#  (u'south_indian', 1),
#  (u'south_indian,_chinese', 1),
#  (u'spanish', 1),
#  (u'sweets_shop', 1),
#  (u'thai', 1),
#  (u'vegan;ice_cream;italian_pizza;indian;vegetarian;local', 1),
#  (u'vegetarian;indian', 1)]

# %% [markdown]
# Different religions and number of places where they are workshipped.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT nodes_tags.value, COUNT(*) as num FROM nodes_tags  JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value="place_of_worship") as i ON nodes_tags.id=i.id WHERE nodes_tags.key="religion" GROUP BY nodes_tags.value ORDER BY num DESC')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'hindu', 125),
#  (u'muslim', 71),
#  (u'christian', 34),
#  (u'buddhist', 13),
#  (u'jain', 6),
#  (u'sikh', 4),
#  (u'zoroastrian', 2),
#  (u'jewish', 1)]

# %% [markdown]
# Different leisures

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT nodes_tags.value, count(*) as num FROM nodes_tags  WHERE nodes_tags.key="leisure" GROUP BY nodes_tags.value ORDER BY num DESC')
all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'park', 63),
#  (u'playground', 20),
#  (u'sports_centre', 15),
#  (u'garden', 10),
#  (u'fitness_centre', 8),
#  (u'pitch', 6),
#  (u'swimming_pool', 4),
#  (u'aquarium', 1),
#  (u'fitness_station', 1),
#  (u'golf_course', 1),
#  (u'stadium', 1)]

# %% [markdown]
# Names of few corrected streets.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT value, count(*) as num FROM nodes_tags WHERE key="street" GROUP BY value ORDER BY num DESC LIMIT 10')

all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'Hanuman Road', 78),
#  (u'Yashavant Nagar Road', 29),
#  (u'Hiranandani Estate', 24),
#  (u'P.L. Lokhande Marg', 24),
#  (u'New Link Road, Andheri West', 21),
#  (u'LBS Marg', 18),
#  (u'Road Number 3', 18),
#  (u'Thane Ghodbunder Road', 18),
#  (u'Eastern Express Highway', 14),
#  (u'GD Somani Road', 13)]

# %% [markdown]
# Cities surrounding mumbai and number of nodes in those cities.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT tags.value, COUNT(*) as count FROM (SELECT * FROM nodes_tags UNION ALL  SELECT * FROM ways_tags) tags WHERE tags.key LIKE "%city" GROUP BY tags.value ORDER BY count DESC LIMIT 10')

all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'Mumbai', 607),
#  (u'Bandra, Mumbai', 566),
#  (u'mumbai', 187),
#  (u'Virar West', 91),
#  (u'Mulund (West)', 79),
#  (u'Navi Mumbai', 70),
#  (u'MUMBAI', 68),
#  (u'Mulund (East)', 62),
#  (u'Thane', 49),
#  (u'Kharghar', 43)]

# %% [markdown]
# Different postcodes in ways_tags after using update postcode function.

# %%
sql_file="mumbai_india.db"
con = sqlite3.connect(sql_file)
cur = con.cursor()
cur.execute('SELECT value, COUNT(*) as count FROM ways_tags WHERE key="postcode" GROUP BY value ORDER BY count')

all_rows=cur.fetchall()
pprint(all_rows)


con.close()
# Out:
# [(u'400007', 1),
#  (u'400010', 1),
#  (u'400011', 1),
#  (u'400034', 1),
#  (u'400035', 1),
#  (u'400038', 1),
#  (u'400047', 1),
#  (u'400059', 1),
#  (u'400060', 1),
#  (u'400066', 1),
#  (u'400082', 1),
#  (u'400095', 1),
#  (u'400096', 1),
#  (u'400602', 1),
#  (u'400605', 1),
#  (u'400703', 1),
#  (u'400709', 1),
#  (u'400710', 1),
#  (u'400950', 1),
#  (u'401104', 1),
#  (u'401105', 1),
#  (u'401209', 1),
#  (u'402205', 1),
#  (u'400015', 2),
#  (u'400020', 2),
#  (u'400025', 2),
#  (u'400030', 2),
#  (u'400054', 2),
#  (u'400055', 2),
#  (u'400068', 2),
#  (u'400069', 2),
#  (u'400079', 2),
#  (u'400091', 2),
#  (u'400098', 2),
#  (u'400103', 2),
#  (u'400612', 2),
#  (u'400701', 2),
#  (u'401101', 2),
#  (u'400008', 3),
#  (u'400024', 3),
#  (u'400031', 3),
#  (u'400037', 3),
#  (u'400042', 3),
#  (u'400056', 3),
#  (u'400063', 3),
#  (u'400092', 3),
#  (u'400101', 3),
#  (u'400102', 3),
#  (u'400708', 3),
#  (u'401202', 3),
#  (u'400052', 4),
#  (u'400077', 4),
#  (u'400104', 4),
#  (u'400606', 4),
#  (u'400705', 4),
#  (u'401201', 4),
#  (u'400016', 5),
#  (u'400022', 5),
#  (u'400049', 5),
#  (u'400062', 5),
#  (u'400078', 5),
#  (u'400097', 5),
#  (u'400099', 5),
#  (u'401107', 5),
#  (u'400013', 6),
#  (u'400014', 6),
#  (u'400018', 6),
#  (u'400028', 6),
#  (u'400058', 6),
#  (u'400075', 7),
#  (u'400607', 7),
#  (u'400601', 8),
#  (u'400012', 9),
#  (u'400072', 9),
#  (u'400086', 9),
#  (u'400043', 10),
#  (u'400021', 11),
#  (u'400094', 12),
#  (u'400001', 13),
#  (u'400004', 13),
#  (u'400061', 13),
#  (u'400076', 14),
#  (u'400706', 14),
#  (u'400067', 15),
#  (u'400093', 15),
#  (u'400051', 17),
#  (u'400064', 19),
#  (u'400089', 19),
#  (u'400071', 20),
#  (u'400088', 21),
#  (u'400002', 24),
#  (u'400080', 26),
#  (u'400074', 28),
#  (u'400057', 36),
#  (u'400070', 38),
#  (u'400081', 38),
#  (u'400053', 44),
#  (u'400005', 47),
#  (u'401303', 85),
#  (u'000000', 88),
#  (u'400050', 551)]

# %% [markdown]
# # Potential Additional Improvements
#
# There are several areas of improvement of the project in the future. The first one is on the completeness of the data. All the above analysis is based on a dataset that reflects a big part of mumbai but not only mumbai. The reason for this is the lack of a way to download a dataset for the entire mumbai without including parts of the neighboring cities. The analyst has to either select a part of the island/city or select a wider area that includes parts of thane and ratnagiri. Also, because of relations between nodes, ways, and relations, the downloaded data expand much further than the actual selection.
#
# As a future improvement, I would download a wider selection or the metro extract from MapZen and filter the non-mumbai nodes and their references. The initial filtering could take place by introducing some latitude/longitude limits in the code to sort out most of the "non-m" nodes.
#
# The second area with room for future improvement is the exploratory analysis of the dataset. Just to mention some of the explorings that could take place:
#
# 1.Distribution of commits per contributor.
#
# 2.Plotting of element creation per type, per day.
#
# 3.Distribution of distance between different types of amenities
#
# 4.Popular franchises in the country (fast food, conventional stores, etc.)
#
# 5.Selection of a bank based on the average distance you have to walk for an ATM.
#
# 6.Which area has the biggest parks and recreation spaces.
#
# The scope of the current project was the wrangling of the dataset, so all the above have been left for future improvement.
#
# Increasing Submissions
#
# Going through this dataset, my concerns were less with the cleanliness of the data - as I found it surprisingly clean - and more with the lack of data. This part of mumbai is too big to have as little information as it does. I think OpenStreetMap can go a long way in developing their map database if they took on certain initiative to increase engagement with their service. One possible initiative would be for OpenStreetMap to form partnerships with educational institutions such as schools, or maybe libraries, to engage students with their service. As a way to develop computer and internet literacy, computer-related courses can teach students how to use OpenStreetMap. It'll expose them to online maps, GPS technology, how to participate in open source projects, and more - all while adding data to a free resource that could benefit the members of the community and the world.
#
# Anticipated Problem: However, the concern here is that you might see an influx of dirty, unreliable data, particularly if the people behind them aren't very computer literate or only participating because it's a mandatory portion of a course. Naturally the data that come from volunteers who get involved because of their genuine passion for the project would be of higher quality.
#
# Ensuring Data Consistency
#
# For data improvement, the biggest problem I came across my data before I cleaned it was the lack of a unified format for street types or phone numbers, or simply incomplete information. If OpenStreetMap had a hard format that street types, phone numbers, zip codes, etc. should follow - and they ensured the format is appropriate for the city/country - there would be much cleaner data for analysis.
#
# Anticipated Problem: The issue here is that you could very likely see a decrease in submissions due to the stricter guidelines.
#
# Finally, open data are here to make average people's life better. For the non-data analyst, it would be nice if there was an application (mobile or web) that could evaluate the suitability of a potential rental house. The work addresses of all family members, importance weights on several amenities like supermarkets, convenience stores, cafes, public transportation, etc. and the application would calculate the suitability of each potential rental. The user would be able to sort them by score and compare them.

# %% [markdown]
# # Conclusion
#
# It's clear from what we've seen that the mumbai OpenStretMap data is still incomplete and incorrect but there is still much in this city to be found and explored. The upside is that a lot of the data that has been entered is fairly clean, so future OSM users who embark on the task of improving the dataset with new information won't have much to worry about with regards to cleaning prior submissions. I'm looking forward to seeing how the data for the area grows overtime, and I hope to also play a role in that mission myself.
